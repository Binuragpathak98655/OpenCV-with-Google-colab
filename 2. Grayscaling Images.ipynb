# %%
import cv2
from matplotlib import pyplot as plt

# %%
def imshow(title ="Image", image = None, size = 10):
  w, h = image.shape[0], image.shape[1]
  aspect_ratio = w/h
  plt.figure(figsize=(size * aspect_ratio, size))
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show()

from google.colab import drive
drive.mount('/content/drive')
# !wget https://drive.google.com/drive/folders/1ldbBZIgCFWt26MkLO3A1e4Vm6Q5P6SmV?usp=sharing
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# --2022-08-30 18:43:35--  https://drive.google.com/drive/folders/1ldbBZIgCFWt26MkLO3A1e4Vm6Q5P6SmV?usp=sharing
# Resolving drive.google.com (drive.google.com)... 173.194.217.100, 173.194.217.138, 173.194.217.113, ...
# Connecting to drive.google.com (drive.google.com)|173.194.217.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://accounts.google.com/ServiceLogin?service=wise&passive=1209600&continue=https://drive.google.com/drive/folders/1ldbBZIgCFWt26MkLO3A1e4Vm6Q5P6SmV?usp%3Dsharing&followup=https://drive.google.com/drive/folders/1ldbBZIgCFWt26MkLO3A1e4Vm6Q5P6SmV?usp%3Dsharing [following]
# ...

# %%
image= cv2.imread('/content/drive/MyDrive/Modern Computer Vision/images/images/IMG_7539.jpg')
imshow("WaldoBeach", image, size=10)

# %%
image.shape[:2]
def imshow(title ="Image", image = None, size = 10):
  w, h = image.shape[0], image.shape[1]
  aspect_ratio = w/h
  plt.figure(figsize=(size * aspect_ratio, size))
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show()
imshow("WaldoBeach", image , size= 10)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
imshow("Converted to Grayscale", gray_image)

# %%
image.shape
# Out:
# (3456, 5184, 3)

# %%
gray_image.shape
# Out:
# (3456, 5184)
